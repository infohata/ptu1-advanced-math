# %%
import pandas as pd
import numpy as np

df = pd.read_csv('miestai.csv')
df
# Out:
#          Miestas    2019    2011    2001    1989    1979    1970    1959  \
# 0        Vilnius  540919  535631  542287  576747  475825  370153  236100
# 1         Kaunas  286763  315993  378650  419745  370000  305600  216850
# 2       Klaipėda  147898  162360  192954  202929  176648  140342   89500
# 3       Šiauliai  100119  109328  133883  145629  118724   92375   59700
# 4      Panevėžys   87148   99690  119749  126483  102303   74497   41100
# ..           ...     ...     ...     ...     ...     ...     ...     ...
# 98       Dusetos     560     717     914    1184    1357    1600    1806
# 99     Kavarskas     528     666     809     972    1113    1191    1287
# 100  Smalininkai     446     515     653     758     805     952    1100
# 101    Troškūnai     372     451     525     672    1174    1417    1495
# 102     Panemunė     210     274     329     398     506     545     539
#
#        1923    1897
# 0    167400  154532
# 1     92446   70920
# 2     35845   20100
# ...

# %%
df.set_index('Miestas', inplace=True)

# %%
for metai in df:
    print(metai)
# Out:
# 2019
# 2011
# 2001
# 1989
# 1979
# 1970
# 1959
# 1923
# 1897

# %%
df
# Out:
#                2019    2011    2001    1989    1979    1970    1959    1923  \
# Miestas
# Vilnius      540919  535631  542287  576747  475825  370153  236100  167400
# Kaunas       286763  315993  378650  419745  370000  305600  216850   92446
# Klaipėda     147898  162360  192954  202929  176648  140342   89500   35845
# Šiauliai     100119  109328  133883  145629  118724   92375   59700   21387
# Panevėžys     87148   99690  119749  126483  102303   74497   41100   19197
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# Dusetos         560     717     914    1184    1357    1600    1806    1164
# Kavarskas       528     666     809     972    1113    1191    1287    1041
# Smalininkai     446     515     653     758     805     952    1100    1741
# Troškūnai       372     451     525     672    1174    1417    1495    1252
# Panemunė        210     274     329     398     506     545     539     637
#
#                1897  mazeja
# Miestas
# ...

# %%
df['mazeja'] = True
for miestas in df.index:
    gyventoju = df.loc[miestas, '2019'].copy()
    for metai in df.columns:
        if metai.isnumeric() and int(metai) < 2019:
            dabar = df.loc[miestas, metai].copy()
            if gyventoju >= dabar:
                df.loc[miestas, 'mazeja'] = False
                break
            gyventoju = dabar.copy()
# DONE
# Out:
# Vilnius 2011
# nebemazeja
# Kaunas 2011
# Kaunas 2001
# Kaunas 1989
# Kaunas 1979
# nebemazeja
# Klaipėda 2011
# Klaipėda 2001
# Klaipėda 1989
# Klaipėda 1979
# nebemazeja
# Šiauliai 2011
# Šiauliai 2001
# Šiauliai 1989
# Šiauliai 1979
# nebemazeja
# Panevėžys 2011
# Panevėžys 2001
# Panevėžys 1989
# Panevėžys 1979
# nebemazeja
# Alytus 2011
# Alytus 2001
# Alytus 1989
# Alytus 1979
# nebemazeja
# Marijampolė 2011
# Marijampolė 2001
# Marijampolė 1989
# Marijampolė 1979
# nebemazeja
# Mažeikiai 2011
# Mažeikiai 2001
# Mažeikiai 1989
# Mažeikiai 1979
# nebemazeja
# Jonava 2011
# Jonava 2001
# Jonava 1989
# Jonava 1979
# nebemazeja
# Utena 2011
# Utena 2001
# Utena 1989
# Utena 1979
# nebemazeja
# Kėdainiai 2011
# Kėdainiai 2001
# Kėdainiai 1989
# Kėdainiai 1979
# nebemazeja
# Tauragė 2011
# Tauragė 2001
# Tauragė 1989
# Tauragė 1979
# nebemazeja
# Telšiai 2011
# Telšiai 2001
# Telšiai 1989
# Telšiai 1979
# nebemazeja
# Ukmergė 2011
# Ukmergė 2001
# Ukmergė 1989
# Ukmergė 1979
# ...

# %%
df[df['mazeja'] == True]
# Out:
#                      2019  2011  2001  1989  1979  1970  1959  1923  1897  \
# Miestas
# Kudirkos Naumiestis  1480  1732  1997  2061  2090  2486  2574  3067  4595
# Žagarė               1366  1712  2312  2649  2918  3386  3800  4730  8285
#
#                      mazeja
# Miestas
# Kudirkos Naumiestis    True
# Žagarė                 True
